# %%
import subprocess
import time
from IPython.display import IFrame

process = subprocess.Popen(
    ['label-studio', 'start', 'my_project', '--host', '0.0.0.0', '--port', '8080'],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE
)

time.sleep(5)

IFrame(src='http://127.0.0.1:8080', width='100%', height=800)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://127.0.0.1:8080"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
